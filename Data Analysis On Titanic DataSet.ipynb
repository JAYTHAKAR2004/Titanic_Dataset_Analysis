# %%
import pandas as pd
titanic=pd.read_csv("C:/Users/Jay/Downloads/titanic.csv")
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
titanic.drop_duplicates(inplace=True)
titanic.reset_index(inplace=True,drop=True)
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
null_counts=titanic.isnull().sum()
if null_counts.sum()>0:
    print(null_counts[null_counts>0])
# Out:
# Age         177
# Cabin       687
# Embarked      2
# dtype: int64

# %%
titanic=titanic[titanic['Embarked'].notna()]
titanic['Age'].fillna(titanic['Age'].median(),inplace=True)
titanic=titanic.drop('Cabin',axis=1)
titanic
# Out:
# C:\Users\Jay\AppData\Local\Temp\ipykernel_14916\2481804149.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic['Age'].fillna(titanic['Age'].median(),inplace=True)
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  28.0      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Embarked
# 0        0         A/5 21171   7.2500        S
# 1        0          PC 17599  71.2833        C
# 2        0  STON/O2. 3101282   7.9250        S
# 3        0            113803  53.1000        S
# 4        0            373450   8.0500        S
# ..     ...               ...      ...      ...
# 886      0            211536  13.0000        S
# 887      0            112053  30.0000        S
# 888      2        W./C. 6607  23.4500        S
# 889      0            111369  30.0000        C
# 890      0            370376   7.7500        Q
#
# [889 rows x 11 columns]

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Embarked        object
# dtype: object

# %%
titanic['Age']=titanic['Age'].astype('int64')

# %%
import seaborn as sns
sns.boxplot(titanic['Survived'])
# Out:
# <Axes: ylabel='Survived'>

# %%
sns.boxplot(titanic['Pclass'])
# Out:
# <Axes: ylabel='Pclass'>

# %%
sns.boxplot(titanic['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
sns.boxplot(titanic['SibSp'])
# Out:
# <Axes: ylabel='SibSp'>

# %%
sns.boxplot(titanic['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %%
titanic=titanic[titanic.Fare<500]

# %%
import numpy as np

# Calculate z-scores for 'Age' and 'SibSp'
z_scores = np.abs((titanic[['Age', 'SibSp']] - titanic[['Age', 'SibSp']].mean()) / titanic[['Age', 'SibSp']].std())

# Define the outlier threshold
outlier_threshold = 3

# Create a boolean mask for outliers
outlier_mask = (z_scores['Age'] > outlier_threshold) | (z_scores['SibSp'] > outlier_threshold)

# Filter the DataFrame for outliers
outliers = titanic[outlier_mask]

# Print the outliers
print(outliers)
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 16            17         0       3                     Rice, Master. Eugene
# 50            51         0       3               Panula, Master. Juha Niilo
# 59            60         0       3       Goodwin, Master. William Frederick
# 68            69         1       3          Andersson, Miss. Erna Alexandra
# 71            72         0       3               Goodwin, Miss. Lillian Amy
# 96            97         0       1                Goldschmidt, Mr. George B
# 116          117         0       3                     Connors, Mr. Patrick
# 119          120         0       3        Andersson, Miss. Ellis Anna Maria
# 159          160         0       3               Sage, Master. Thomas Henry
# 164          165         0       3             Panula, Master. Eino Viljami
# 171          172         0       3                     Rice, Master. Arthur
# 180          181         0       3             Sage, Miss. Constance Gladys
# 182          183         0       3    Asplund, Master. Clarence Gustaf Hugo
# 201          202         0       3                      Sage, Mr. Frederick
# 233          234         1       3           Asplund, Miss. Lillian Gertrud
# 261          262         1       3        Asplund, Master. Edvin Rojj Felix
# 266          267         0       3                Panula, Mr. Ernesti Arvid
# 278          279         0       3                       Rice, Master. Eric
# 324          325         0       3                 Sage, Mr. George John Jr
# 386          387         0       3          Goodwin, Master. Sidney Leonard
# 480          481         0       3           Goodwin, Master. Harold Victor
# 493          494         0       1                  Artagaveytia, Mr. Ramon
# 541          542         0       3     Andersson, Miss. Ingeborg Constanzia
# 542          543         0       3        Andersson, Miss. Sigrid Elisabeth
# 630          631         1       1     Barkworth, Mr. Algernon Henry Wilson
# 672          673         0       2              Mitchell, Mr. Henry Michael
# 683          684         0       3              Goodwin, Mr. Charles Edward
# 686          687         0       3                 Panula, Mr. Jaako Arnold
# 745          746         0       1             Crosby, Capt. Edward Gifford
# 787          788         0       3                Rice, Master. George Hugh
# 792          793         0       3                  Sage, Miss. Stella Anna
# 813          814         0       3       Andersson, Miss. Ebba Iris Alfrida
# 824          825         0       3             Panula, Master. Urho Abraham
# 846          847         0       3                 Sage, Mr. Douglas Bullen
# 850          851         0       3  Andersson, Master. Sigvard Harald Elias
# 851          852         0       3                      Svensson, Mr. Johan
# 863          864         0       3        Sage, Miss. Dorothy Edith "Dolly"
#
#         Sex  Age  SibSp  Parch      Ticket     Fare Embarked
# 16     male    2      4      1      382652  29.1250        Q
# 50     male    7      4      1     3101295  39.6875        S
# 59     male   11      5      2     CA 2144  46.9000        S
# 68   female   17      4      2     3101281   7.9250        S
# 71   female   16      5      2     CA 2144  46.9000        S
# 96     male   71      0      0    PC 17754  34.6542        C
# 116    male   70      0      0      370369   7.7500        Q
# 119  female    2      4      2      347082  31.2750        S
# 159    male   28      8      2    CA. 2343  69.5500        S
# 164    male    1      4      1     3101295  39.6875        S
# 171    male    4      4      1      382652  29.1250        Q
# 180  female   28      8      2    CA. 2343  69.5500        S
# 182    male    9      4      2      347077  31.3875        S
# 201    male   28      8      2    CA. 2343  69.5500        S
# 233  female    5      4      2      347077  31.3875        S
# 261    male    3      4      2      347077  31.3875        S
# 266    male   16      4      1     3101295  39.6875        S
# 278    male    7      4      1      382652  29.1250        Q
# 324    male   28      8      2    CA. 2343  69.5500        S
# 386    male    1      5      2     CA 2144  46.9000        S
# 480    male    9      5      2     CA 2144  46.9000        S
# 493    male   71      0      0    PC 17609  49.5042        C
# 541  female    9      4      2      347082  31.2750        S
# 542  female   11      4      2      347082  31.2750        S
# 630    male   80      0      0       27042  30.0000        S
# 672    male   70      0      0  C.A. 24580  10.5000        S
# 683    male   14      5      2     CA 2144  46.9000        S
# 686    male   14      4      1     3101295  39.6875        S
# 745    male   70      1      1   WE/P 5735  71.0000        S
# 787    male    8      4      1      382652  29.1250        Q
# 792  female   28      8      2    CA. 2343  69.5500        S
# 813  female    6      4      2      347082  31.2750        S
# 824    male    2      4      1     3101295  39.6875        S
# 846    male   28      8      2    CA. 2343  69.5500        S
# 850    male    4      4      2      347082  31.2750        S
# 851    male   74      0      0      347060   7.7750        S
# 863  female   28      8      2    CA. 2343  69.5500        S

# %%
age_threshold=titanic['Age'].quantile(0.95)
SibSp_threshold=titanic['SibSp'].quantile(0.95)
titanic['Age']=np.where(titanic['Age']>age_threshold,age_threshold,titanic['Age'])
titanic['SibSp']=np.where(titanic['SibSp']>age_threshold,age_threshold,titanic['SibSp'])
# Out:
# C:\Users\Jay\AppData\Local\Temp\ipykernel_14916\2521602717.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titanic['Age']=np.where(titanic['Age']>age_threshold,age_threshold,titanic['Age'])
# C:\Users\Jay\AppData\Local\Temp\ipykernel_14916\2521602717.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titanic['SibSp']=np.where(titanic['SibSp']>age_threshold,age_threshold,titanic['SibSp'])

# %%
titanic.drop_duplicates(inplace=True)
titanic.reset_index(inplace=True,drop=True)
titanic
# Out:
# C:\Users\Jay\AppData\Local\Temp\ipykernel_14916\2748852534.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titanic.drop_duplicates(inplace=True)
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 881          887         0       2
# 882          888         1       1
# 883          889         0       3
# 884          890         1       1
# 885          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0    1.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 2                               Heikkinen, Miss. Laina  female  26.0    0.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# 4                             Allen, Mr. William Henry    male  35.0    0.0
# ..                                                 ...     ...   ...    ...
# 881                              Montvila, Rev. Juozas    male  27.0    0.0
# 882                       Graham, Miss. Margaret Edith  female  19.0    0.0
# 883           Johnston, Miss. Catherine Helen "Carrie"  female  28.0    1.0
# 884                              Behr, Mr. Karl Howell    male  26.0    0.0
# 885                                Dooley, Mr. Patrick    male  32.0    0.0
#
#      Parch            Ticket     Fare Embarked
# 0        0         A/5 21171   7.2500        S
# 1        0          PC 17599  71.2833        C
# 2        0  STON/O2. 3101282   7.9250        S
# 3        0            113803  53.1000        S
# 4        0            373450   8.0500        S
# ..     ...               ...      ...      ...
# 881      0            211536  13.0000        S
# 882      0            112053  30.0000        S
# 883      2        W./C. 6607  23.4500        S
# 884      0            111369  30.0000        C
# 885      0            370376   7.7500        Q
#
# [886 rows x 11 columns]

# %%
# Group by 'Survived' and calculate the mean of numeric columns
survived = titanic.groupby('Survived').mean(numeric_only=True)

# Print the result
print(survived)
# Out:
#           PassengerId    Pclass        Age     SibSp     Parch       Fare
# Survived
# 0          447.016393  2.531876  29.564663  0.553734  0.329690  22.117887
# 1          443.338279  1.964392  27.842730  0.480712  0.468843  44.077869

# %%
female_passengers=titanic[titanic.Sex=='female']
female_passengers
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          881         1       2
# 877          883         0       3
# 880          886         0       3
# 882          888         1       1
# 883          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 2                               Heikkinen, Miss. Laina  female  26.0    0.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0    0.0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0    1.0
# ..                                                 ...     ...   ...    ...
# 875       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0    0.0
# 877                       Dahlberg, Miss. Gerda Ulrika  female  22.0    0.0
# 880               Rice, Mrs. William (Margaret Norton)  female  39.0    0.0
# 882                       Graham, Miss. Margaret Edith  female  19.0    0.0
# 883           Johnston, Miss. Catherine Helen "Carrie"  female  28.0    1.0
#
#      Parch            Ticket     Fare Embarked
# 1        0          PC 17599  71.2833        C
# 2        0  STON/O2. 3101282   7.9250        S
# 3        0            113803  53.1000        S
# 8        2            347742  11.1333        S
# 9        0            237736  30.0708        C
# ..     ...               ...      ...      ...
# 875      1            230433  26.0000        S
# 877      0              7552  10.5167        S
# 880      5            382652  29.1250        Q
# 882      0            112053  30.0000        S
# 883      2        W./C. 6607  23.4500        S
#
# [311 rows x 11 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(8,6))
sns.histplot(data=titanic,x='Age',hue='Survived',bins=30,kde=True)
plt.title('Distribution of the passengers by Age and survival')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.histplot(data=titanic,x='Pclass',hue='Survived')
plt.title('Count of passengers by Cabin Class and survival')
plt.show()
